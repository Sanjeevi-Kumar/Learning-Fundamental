# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 6.5 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.1 MB 7.4 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.1 MB 7.9 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 8.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 9.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ------------------- -------------------- 3.4/7.0 MB 15.9 MB/s eta 0:00:01
#    ---------------------------------------  6.8/7.0 MB 18.4 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[1,10,30,20,5]
plt.plot(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("line plot")
plt.show()

# %%
plt.plot(x,y,color="violet",linestyle="--",marker="o",linewidth=3,markersize=10)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(x,y,color="red")
plt.title("X vs Y")
plt.subplot(1,2,2)
plt.plot(y,x,color="blue")
plt.title("Y vs X")
plt.show()

# %% [markdown]
# **Histogram**

# %%
plt.hist([1,2,3,4,5,6,6,7,2,2,5,7,7,7,7,7],bins=5)
plt.yticks(range(1, 10))
# Out:
# ([<matplotlib.axis.YTick at 0x1e03db31e50>,
# ...
#  [Text(0, 1, '1'),
#   Text(0, 2, '2'),
#   Text(0, 3, '3'),
#   Text(0, 4, '4'),
#   Text(0, 5, '5'),
#   Text(0, 6, '6'),
#   Text(0, 7, '7'),
#   Text(0, 8, '8'),
#   Text(0, 9, '9')])

# %% [markdown]
# **Scatterplot**

# %%
x=[1,2,3,4,5]
y=[1,4,6,8,10]
plt.scatter(x,y)

# %%
import matplotlib.pyplot as plt

labels = ["A", "B", "C", "D", "E"]
data = [10, 20, 30, 40, 50]
colors = ["red", "pink", "blue", "green", "orange"]

plt.pie(data, labels=labels, colors=colors,autopct="%.1f%%")
plt.show()

# %% [markdown]
# **Visualize using DataFrame**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("..\pandas\Automobile.csv")
data
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_7620\498813448.py:1: SyntaxWarning: invalid escape sequence '\p'
#   data=pd.read_csv("..\pandas\Automobile.csv")
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# ...

# %%
average_displacement=data.groupby("origin")["displacement"].mean()
average_displacement
# Out:
# origin
# europe    109.142857
# japan     102.708861
# usa       245.901606
# Name: displacement, dtype: float64

# %%
average_displacement.plot(kind="line",color="violet")
# Out:
# <Axes: xlabel='origin'>

# %%
data.columns
# Out:
# Index(['name', 'mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin'],
#       dtype='object')

# %%
orgin_year_cylinder=data.groupby(["origin","model_year"])["cylinders"].mean()
orgin_year_cylinder
# Out:
# origin  model_year
# europe  70            4.000000
#         71            4.000000
#         72            4.000000
#         73            4.000000
#         74            4.000000
#         75            4.000000
#         76            4.250000
#         77            4.000000
#         78            4.833333
#         79            4.250000
#         80            4.111111
#         81            4.500000
#         82            4.000000
# japan   70            4.000000
#         71            4.000000
#         72            3.800000
#         73            4.250000
#         74            4.000000
#         75            4.000000
#         76            4.500000
#         77            4.166667
#         78            4.000000
#         79            4.000000
#         80            4.076923
#         81            4.333333
#         82            4.000000
# usa     70            7.636364
#         71            6.200000
#         72            6.888889
# ...

# %%
df['origin'].unique()
# Out:
# array(['europe', 'japan', 'usa'], dtype=object)

# %%
import matplotlib.pyplot as plt

# Reset index to convert MultiIndex to columns
df = orgin_year_cylinder.reset_index()

# Plot
plt.figure(figsize=(10, 6))
for origin in df['origin'].unique():
    subset = df[df['origin'] == origin]
    plt.plot(subset['model_year'], subset['cylinders'], label=f"Origin: {origin}")

plt.xlabel("Model Year")
plt.ylabel("Average Cylinders")
plt.title("Average Cylinder Count by Origin and Model Year")
plt.legend()
plt.grid(True)
plt.show()

# %%
data.isnull().count()
# Out:
# name            398
# mpg             398
# cylinders       398
# displacement    398
# horsepower      398
# weight          398
# acceleration    398
# model_year      398
# origin          398
# dtype: int64

# %%
data.dtypes
# Out:
# name             object
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# dtype: object

# %%
plt.scatter(data=data, x="horsepower", y="mpg")
